# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r'Book1.xlsx')
df
# Out:
#       Unnamed: 0 course_id                                       course_title  \
# 0              0   1070968                 Ultimate Investment Banking Course
# 1              1   1113822  Complete GST Course & Certification - Grow You...
# 2              2   1006314  Financial Modeling for Business Analysts and C...
# 3              3   1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4              4   1011058       How To Maximize Your Profits Trading Options
# ...          ...       ...                                                ...
# 3684        3678    775618  Learn jQuery from Scratch - Master of JavaScri...
# 3685        3679   1088178  How To Design A WordPress Website With No Codi...
# 3686        3680    635248                      Learn and Build using Polymer
# 3687        3681    905096  CSS Animations: Create Amazing Effects on Your...
# 3688        3682    297602  Using MODX CMS to Build Websites: A Beginner's...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3689 entries, 0 to 3688
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           3689 non-null   int64
#  1   course_id            3689 non-null   object
#  2   course_title         3689 non-null   object
#  3   url                  3676 non-null   object
#  4   is_paid              3676 non-null   object
#  5   price                3676 non-null   object
#  6   num_subscribers      3676 non-null   float64
#  7   num_reviews          3676 non-null   float64
#  8   num_lectures         3676 non-null   object
#  9   level                3676 non-null   object
#  10  content_duration     3676 non-null   object
#  11  published_timestamp  3676 non-null   object
#  12  subject              3676 non-null   object
#  13  clean_course_title   3650 non-null   object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 403.6+ KB

# %%
df.head()
# Out:
#    Unnamed: 0 course_id                                       course_title  \
# 0           0   1070968                 Ultimate Investment Banking Course
# 1           1   1113822  Complete GST Course & Certification - Grow You...
# 2           2   1006314  Financial Modeling for Business Analysts and C...
# 3           3   1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4   1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
# 3  https://www.udemy.com/complete-excel-finance-c...    True    95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True   200
#
#    num_subscribers  num_reviews num_lectures               level  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject',
#        'clean_course_title'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# course_id               0
# course_title            0
# url                    13
# is_paid                13
# price                  13
# num_subscribers        13
# num_reviews            13
# num_lectures           13
# level                  13
# content_duration       13
# published_timestamp    13
# subject                13
# clean_course_title     39
# dtype: int64

# %% [markdown]
# # SUPJECT

# %%
df.loc[df['subject'].str.len() > 30, 'subject'] = None

# %%
df = df.dropna(subset=['subject'])

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
len(df['subject'].unique())
# Out:
# 4

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1198
# Business Finance       1197
# Musical Instruments     673
# Graphic Design          602
# Name: count, dtype: int64

# %%
df['subject'].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
df['subject'].value_counts().plot(kind='pie')

plt.show()

# %% [markdown]
# #  using seaborn

# %%
plt.Figure(figsize=(8,8))
sns.countplot(x=df['subject'],data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # num_subscribers

# %%
df.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1867708.0
# Graphic Design         1062958.0
# Musical Instruments     838170.0
# Web Development        7965682.0
# Name: num_subscribers, dtype: float64

# %%
df['num_subscribers'].mean()
# Out:
# np.float64(3197.416348773842)

# %%
df['num_subscribers'].max()
# Out:
# np.float64(268923.0)

# %%
df['num_subscribers'].min()
# Out:
# np.float64(0.0)

# %%
df['num_subscribers'].sum()
# Out:
# np.float64(11734518.0)

# %%
df['num_subscribers'].idxmax()
# Out:
# np.int64(2838)

# %%
df.iloc[2838]
# Out:
# Unnamed: 0                                                          2849
# course_id                                                         752432
# course_title           How to Create a Website Without Coding - WordP...
# url                    https://www.udemy.com/how-to-create-a-website-...
# is_paid                                                             True
# price                                                                195
# num_subscribers                                                   9056.0
# num_reviews                                                         96.0
# num_lectures                                                          31
# level                                                     Beginner Level
# content_duration                                               1.5 hours
# published_timestamp                                 2016-02-04T22:22:22Z
# subject                                                  Web Development
# ...

# %% [markdown]
# # level

# %%
df['level'].value_counts()
# Out:
# level
# All Levels            1924
# Beginner Level        1267
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df['level'].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
df['level'].value_counts().plot(kind='pie')
plt.show()

# %%
df[['num_subscribers','level']]
# Out:
#       num_subscribers               level
# 0              2147.0          All Levels
# 1              2792.0          All Levels
# 2              2174.0  Intermediate Level
# 3              2451.0          All Levels
# 4              1276.0  Intermediate Level
# ...               ...                 ...
# 3684           1040.0          All Levels
# 3685            306.0      Beginner Level
# 3686            513.0          All Levels
# 3687            300.0          All Levels
# 3688            901.0      Beginner Level
#
# [3670 rows x 2 columns]

# %%
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6890616.0
# Beginner Level        4051701.0
# Expert Level            50196.0
# Intermediate Level     742005.0
# Name: num_subscribers, dtype: float64

# %%
df.groupby('level')['num_subscribers'].sum().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('level')['num_subscribers'].sum().plot(kind='pie')
plt.show()

# %%
df.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            698
#                      Beginner Level        340
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        242
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        294
#                      All Levels            271
#                      Intermediate Level    101
#                      Expert Level            7
# Web Development      All Levels            657
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: count, dtype: int64

# %%
df.groupby('subject')['level'].value_counts().plot(kind='barh')
plt.show()

# %%
# using seaborn
plt.figure(figsize=(20,10))
sns.barplot(x="level", y="num_subscribers", data=df, hue="subject")
plt.show()

# %%
df.head(3)
# Out:
#    Unnamed: 0 course_id                                       course_title  \
# 0           0   1070968                 Ultimate Investment Banking Course
# 1           1   1113822  Complete GST Course & Certification - Grow You...
# 2           2   1006314  Financial Modeling for Business Analysts and C...
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
#
#    num_subscribers  num_reviews num_lectures               level  \
# 0           2147.0         23.0           51          All Levels
# 1           2792.0        923.0          274          All Levels
# 2           2174.0         74.0           51  Intermediate Level
#
#   content_duration   published_timestamp           subject  \
# 0        1.5 hours  2017-01-18T20:58:58Z  Business Finance
# ...

# %%
def func_drow(x):
    plt.figure(figsize=(20,10))
    sns.barplot(x='level', y=x, data=df,hue='subject')
    plt.title('plot of {} par level par supject'.format(x))
    plt.show()

    # Pie Chart
    plt.figure(figsize=(10, 10))
    df.groupby('level')[x].sum().plot(kind='pie')
    plt.title('plot of {} per level'.format(x))
    plt.show()

# %%
func_drow('num_lectures')
# Out:
# C:\Users\AHMED ALNGER\AppData\Local\Temp\ipykernel_13516\2122755966.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.groupby('level')[x].sum().plot(kind='pie')

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     308
# Name: count, dtype: int64

# %%
df['is_paid'].value_counts().plot(kind='pie')
plt.show()

# %%
df['is_paid'].value_counts()
plt.Figure(figsize=(20,10))
sns.countplot(x=df['is_paid'])
plt.show()

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
df.groupby('is_paid')['subject'].value_counts().plot(kind='bar')
plt.show()

# %%
df['published_timestamp']
# Out:
# 0       2017-01-18T20:58:58Z
# 1       2017-03-09T16:34:20Z
# 2       2016-12-19T19:26:30Z
# 3       2017-05-30T20:07:24Z
# 4       2016-12-13T14:57:18Z
#                 ...
# 3684    2016-06-14T17:36:46Z
# 3685    2017-03-10T22:24:30Z
# 3686    2015-12-30T16:41:42Z
# 3687    2016-08-11T19:06:15Z
# 3688    2014-09-28T19:51:11Z
# Name: published_timestamp, Length: 3670, dtype: object

# %%
df['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3684    [2016-06-14, 17:36:46Z]
# 3685    [2017-03-10, 22:24:30Z]
# 3686    [2015-12-30, 16:41:42Z]
# 3687    [2016-08-11, 19:06:15Z]
# 3688    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3670, dtype: object

# %%
df.loc[:, 'published_date'] = df['published_timestamp'].str.split('T').str.get(0)

# %%
df.loc[:, 'published_date'] = pd.to_datetime(df['published_date'])

# %%
df['published_date']
# Out:
# 0      2017-01-18
# 1      2017-03-09
# 2      2016-12-19
# 3      2017-05-30
# 4      2016-12-13
#           ...
# 3684   2016-06-14
# 3685   2017-03-10
# 3686   2015-12-30
# 3687   2016-08-11
# 3688   2014-09-28
# Name: published_date, Length: 3670, dtype: datetime64[ns]

# %%
df.head(2)
# Out:
#    Unnamed: 0 course_id                                       course_title  \
# 0           0   1070968                 Ultimate Investment Banking Course
# 1           1   1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   NaN
# 1      https://www.udemy.com/goods-and-services-tax/    True   NaN
#
#    num_subscribers  num_reviews num_lectures       level content_duration  \
# 0           2147.0         23.0           51  All Levels        1.5 hours
# 1           2792.0        923.0          274  All Levels         39 hours
#
#     published_timestamp           subject  \
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance
#
#                                   clean_course_title published_date
# 0                 Ultimate Investment Banking Course     2017-01-18
# ...

# %%
df.loc[:, 'year'] = df['published_date'].dt.year
df.loc[:, 'month'] = df['published_date'].dt.month
df.loc[:, 'day'] = df['published_date'].dt.day

# %%
df['year']
# Out:
# 0       2017
# 1       2017
# 2       2016
# 3       2017
# 4       2016
#         ...
# 3684    2016
# 3685    2017
# 3686    2015
# 3687    2016
# 3688    2014
# Name: year, Length: 3670, dtype: int32

# %%
df['year'].unique()
# Out:
# array([2017, 2016, 2014, 2015, 2013, 2012, 2011], dtype=int32)

# %%
df.groupby('year')['num_subscribers'].sum()
# Out:
# year
# 2011     119028.0
# 2012     555339.0
# 2013    1717167.0
# 2014    1930248.0
# 2015    3473992.0
# 2016    2947771.0
# 2017     990973.0
# Name: num_subscribers, dtype: float64

# %%
df.groupby('year')['num_subscribers'].sum().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(x='year', y='num_subscribers', data=df, hue='subject', errorbar=None)
plt.title('plot of subscription per year per subject category')
plt.show()
